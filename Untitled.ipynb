# %%
import pandas as pd

# %%
import seaborn as sb

# %%
aids = pd.read_csv("aids.csv")

# %%
plot = aids.query("Country == 'Angola'")

# %%
sb.lineplot(data=plot, x="Year", y="Data.HIV Prevalence.Adults")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Data.HIV Prevalence.Adults'>
